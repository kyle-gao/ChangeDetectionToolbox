# %% [markdown]
# <a href="https://colab.research.google.com/github/kyle-gao/ChangeDetectionToolbox/blob/master/ClassicalChangeDetectionBenchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matlab code from https://github.com/Bobholamovic/ChangeDetectionToolbox
# ##Evaluated on the OSCD dataset https://ieee-dataport.org/open-access/oscd-onera-satellite-change-detection

# %% [markdown]
# #CVA-KMeans

# %% [markdown]
# ![CVAKMeans.png](data:image/png;base64,...)

# %% [markdown]
# #CVA-OTSU

# %% [markdown]
# ![CVAKOTSU.png](data:image/png;base64,...)

# %% [markdown]
# #Image Diff-KMeans

# %% [markdown]
# ![ImgdiffKMeans.png](data:image/png;base64,...)

# %% [markdown]
# #Image Diff-OTSU

# %% [markdown]
# ![ImgdiffOTSU.png](data:image/png;base64,...)

# %%
import os
import zipfile
import pandas as pd

# %%
with zipfile.ZipFile("/content/Results.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/Results/")

# %%
filenames = os.listdir("/content/Results")
results = [pd.read_excel("/content/Results/"+filename) for filename in filenames]
resultsdf = pd.concat(results)

# %%
resultsdf.sort_values("OA",ascending=False)
# Out:
#                                         name  threAlg  ...    Recall        UA
# 0  Differential Principal Component Analysis     OTSU  ...  0.309427  0.134831
# 0  Differential Principal Component Analysis  K-Means  ...  0.236709  0.158942
# 0                   Iterative Reweighted MAD  K-Means  ...  0.399894  0.100352
# 0                   Iterative Reweighted MAD     OTSU  ...  0.411706  0.085047
# 0  Principal Component Differential Analysis  K-Means  ...  0.402528  0.151257
# 0  Principal Component Differential Analysis     OTSU  ...  0.380435  0.097890
# 0                           Image Regression  K-Means  ...  0.413733  0.158152
# 0                           Image Regression     OTSU  ...  0.504935  0.167473
# 0          Multivariate Alteration Detection  K-Means  ...  0.590690  0.127014
# 0          Multivariate Alteration Detection     OTSU  ...  0.478706  0.083749
# 0               Change Detection PCA k-Means  K-Means  ...  0.376523  0.064178
# ...
